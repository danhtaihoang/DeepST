# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import sys

import openslide
from openslide import deepzoom
import cv2 as cv
from PIL import Image, ImageDraw

# %%
project = "BRCA"
ik = 4
il = 0

# %%
i_slides_train_valid_test = np.load("../16patients_split/i_slides_nested_%s.npz"%project, allow_pickle=True)
i_slides_test = i_slides_train_valid_test["i_slides_test"][ik]
#print(i_slides_test)

#i_slide = i_slides_test[0]
#print("i_slide:", i_slide)

# %%
## load tile information and tile score:
tile = np.load("../12tiles_from_slide/tiles_selected/tiles_selected_npy/%s_tiles_selected.npy"%project, allow_pickle=True)

tile_scores = np.load("tile_scores_%s_ik%s_il%s.npy"%(project, ik, il), allow_pickle=True)

### gene names
best_genes = np.loadtxt("220Nov21BRCA_nonrot_ik4_il0/R_sorted.txt", dtype="str")
best_genes = best_genes[:,0]
#print("best_genes:", best_genes)
genes = np.loadtxt("../15select_genes/%s_gene_active90_mediansorted_names.txt"%project, dtype="str")
genes = genes[:,5]
i_genes = np.array([np.argwhere(genes == best_gene)[0][0] for best_gene in best_genes])

i_genes = i_genes[:5]

# %%
for i_slide in i_slides_test[:80]:
    
    ### Load tile_selected information
    n_slides = len(tile)
    print("n_slides:", n_slides)

    i_slides = np.array([tile[i][0] for i in range(n_slides)])
    #print("i_slides:", i_slides)

    i0 = np.argwhere(i_slides == i_slide)[0][0]
    print("i0:", i0)

    slide_name = tile[i0][1]
    print("slide_name:", slide_name)

    slide_level = tile[i0][2]
    print("slide_level:", slide_level)

    idx_row_col = tile[i0][3]
    print("idx_row_col.shape:", idx_row_col.shape)
    #print(idx_row_col)

    ##------------------------------------
    ### Load tile_score
    n_slides = len(tile_scores)
    print("n_slides:", n_slides)

    i_slides = np.array([tile_scores[i][0] for i in range(n_slides)])
    #print("i_slides:", i_slides)

    i0 = np.argwhere(i_slides == i_slide)[0][0]
    print("i0:", i0)

    print("i_slide:", tile_scores[i0][0])
    print("slide_name:", tile_scores[i0][1])
    scores = tile_scores[i0][2]
    print("scores.shape", scores.shape)


    ### Load image
    ##------------------------------------
    tile_size = 512
    mask_downsampling = 16
    magnification = 20

    path2slides = "../%s_slides_data_test"%project

    slide = openslide.OpenSlide("%s/%s.svs"%(path2slides, slide_name))

    ## magnification max
    if openslide.PROPERTY_NAME_OBJECTIVE_POWER in slide.properties:
        magnification_max = slide.properties[openslide.PROPERTY_NAME_OBJECTIVE_POWER]
    else:
        print('[WARNING] openslide.PROPERTY_NAME_OBJECTIVE_POWER was not found. Assuming it is 40X, i_slide:', i_slide)
        magnification_max = 40

    #print("magnification_max:", magnification_max)

    ## downsample_level
    downsampling = int(int(magnification_max)/magnification)
    print("downsampling:", downsampling)

    ##------------------------------------

    slide_gen = deepzoom.DeepZoomGenerator(slide, tile_size=tile_size, overlap=0)
    slide_gen_selectedlevel_idx = slide_level
    print("slide_gen_selectedlevel_idx:", slide_gen_selectedlevel_idx)

    slide_gen_selectedlevel_dims = slide_gen.level_dimensions[slide_gen_selectedlevel_idx]
    print("slide_gen_selectedlevel_dims:", slide_gen_selectedlevel_dims)

    ### Downsampling
    best_downsampling_level = slide.get_best_level_for_downsample(mask_downsampling + 0.1)
    print("best_downsampling_level:", best_downsampling_level)
    print("slide.level_dimensions[best_downsampling_level]:", slide.level_dimensions[best_downsampling_level])

    # image at the best level
    img_best_level = slide.read_region((0, 0), best_downsampling_level, 
                               slide.level_dimensions[best_downsampling_level])
    print(img_best_level.size)

    target_size = tuple([int(x//mask_downsampling) for x in slide.dimensions])
    print("target_size:", target_size)

    ## resize the image to the target size
    img = img_best_level.resize(target_size)
    print("img.size:",img.size)
    #plt.imshow(img)

    ## remove the alpha channel and convert to numpy
    #img_RGB = np.array(img.convert("RGB"))
    #print("img.shape - RGB:", img_RGB.shape)
    #plt.imshow(img_RGB)

    mask_tile_size = int(np.ceil(tile_size*(downsampling/mask_downsampling)))
    print("mask_tile_size:", mask_tile_size)

    ##----------------------------------------------------------
    heatmap = np.zeros((img.size[1], img.size[0]))
    print("heatmap.shape", heatmap.shape)

    rows = idx_row_col[:,1]
    cols = idx_row_col[:,2]

    ##----------------------------------------------------------
    nx,ny = 6,1
    fig, ax = plt.subplots(ny,nx,figsize=(nx*8,ny*6))

    ax[0].imshow(img)

    for iax, i_gene in enumerate(i_genes):
        score = scores[:,i_gene]

        score = score - score.min()

        #print("score.shape:", score.shape)

        for i in range(len(rows)):
            heatmap[int(rows[i]*mask_tile_size):int((rows[i]+1)*mask_tile_size), 
                int(cols[i]*mask_tile_size):int((cols[i]+1)*mask_tile_size)] = score[i]

        #ax[iax+1].imshow(heatmap, interpolation="nearest")
        ax[iax+1].imshow(heatmap)
        #plt.clim(0,3)

    #plt.colorbar(im,ax=ax[1],fraction=0.045, pad=0.05,ticks=[-1.0,0,1.0])

    plt.tight_layout(h_pad=1, w_pad= 0.5)
    plt.savefig('heatmap_all/heatmap_slide%s.pdf'%(i_slide), format='pdf', dpi=50)
    plt.close()

    print("--- completed i_slide ---:", i_slide)
# Out:
# n_slides: 1033
# i0: 0
# slide_name: BRCA_00000_0001a1fb-f388-41c6-bfe9-ecbb10429e37
# slide_level: 16
# idx_row_col.shape: (4435, 3)
# n_slides: 206
# i0: 0
# i_slide: 0
# slide_name: BRCA_00000_0001a1fb-f388-41c6-bfe9-ecbb10429e37
# scores.shape (4435, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (61437, 36668)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (7679, 4583)
# (7679, 4583)
# target_size: (7679, 4583)
# img.size: (7679, 4583)
# mask_tile_size: 64
# heatmap.shape (4583, 7679)
# --- completed i_slide ---: 0
# n_slides: 1033
# i0: 2
# slide_name: BRCA_00002_01254d79-23ab-4163-8e71-7605041c1b82
# slide_level: 17
# idx_row_col.shape: (1024, 3)
# n_slides: 206
# i0: 1
# i_slide: 2
# slide_name: BRCA_00002_01254d79-23ab-4163-8e71-7605041c1b82
# scores.shape (1024, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 17
# slide_gen_selectedlevel_dims: (69425, 21348)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (8678, 2668)
# (8678, 2668)
# target_size: (8678, 2668)
# img.size: (8678, 2668)
# mask_tile_size: 64
# heatmap.shape (2668, 8678)
# --- completed i_slide ---: 2
# n_slides: 1033
# i0: 11
# slide_name: BRCA_00011_036ba8d7-fa83-448a-b87a-9044016b0143
# slide_level: 16
# idx_row_col.shape: (2165, 3)
# n_slides: 206
# i0: 2
# i_slide: 11
# slide_name: BRCA_00011_036ba8d7-fa83-448a-b87a-9044016b0143
# scores.shape (2165, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (43316, 43059)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (5414, 5382)
# (5414, 5382)
# target_size: (5414, 5382)
# img.size: (5414, 5382)
# mask_tile_size: 64
# heatmap.shape (5382, 5414)
# --- completed i_slide ---: 11
# n_slides: 1033
# i0: 28
# slide_name: BRCA_00028_071313a3-24eb-4cc6-903c-1ba779267083
# slide_level: 15
# idx_row_col.shape: (1090, 3)
# n_slides: 206
# i0: 3
# i_slide: 28
# slide_name: BRCA_00028_071313a3-24eb-4cc6-903c-1ba779267083
# scores.shape (1090, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 15
# slide_gen_selectedlevel_dims: (32368, 29473)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (4046, 3684)
# (4046, 3684)
# target_size: (4046, 3684)
# img.size: (4046, 3684)
# mask_tile_size: 64
# heatmap.shape (3684, 4046)
# --- completed i_slide ---: 28
# n_slides: 1033
# i0: 31
# slide_name: BRCA_00031_07b37c50-7594-402f-bf16-89a498d1b7ae
# slide_level: 17
# idx_row_col.shape: (3287, 3)
# n_slides: 206
# i0: 4
# i_slide: 31
# slide_name: BRCA_00031_07b37c50-7594-402f-bf16-89a498d1b7ae
# scores.shape (3287, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 17
# slide_gen_selectedlevel_dims: (72828, 32715)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (9103, 4089)
# (9103, 4089)
# target_size: (9103, 4089)
# img.size: (9103, 4089)
# mask_tile_size: 64
# heatmap.shape (4089, 9103)
# --- completed i_slide ---: 31
# n_slides: 1033
# i0: 35
# slide_name: BRCA_00035_087d06b2-bb36-44d9-9ee9-9887305b090f
# slide_level: 15
# idx_row_col.shape: (900, 3)
# n_slides: 206
# i0: 5
# i_slide: 35
# slide_name: BRCA_00035_087d06b2-bb36-44d9-9ee9-9887305b090f
# scores.shape (900, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 15
# slide_gen_selectedlevel_dims: (29036, 23114)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (3629, 2889)
# (3629, 2889)
# target_size: (3629, 2889)
# img.size: (3629, 2889)
# mask_tile_size: 64
# heatmap.shape (2889, 3629)
# --- completed i_slide ---: 35
# n_slides: 1033
# i0: 43
# slide_name: BRCA_00043_0a1a9917-c947-43b5-b04d-7cdf5ac715be
# slide_level: 16
# idx_row_col.shape: (3906, 3)
# n_slides: 206
# i0: 6
# i_slide: 43
# slide_name: BRCA_00043_0a1a9917-c947-43b5-b04d-7cdf5ac715be
# scores.shape (3906, 22884)
# downsampling: 1
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (59759, 38737)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (3734, 2421)
# (3734, 2421)
# target_size: (3734, 2421)
# img.size: (3734, 2421)
# mask_tile_size: 32
# heatmap.shape (2421, 3734)
# --- completed i_slide ---: 43
# n_slides: 1033
# i0: 45
# slide_name: BRCA_00045_0a384d70-52d9-4005-9a7c-b57434b03f47
# slide_level: 17
# idx_row_col.shape: (1793, 3)
# n_slides: 206
# i0: 7
# i_slide: 45
# slide_name: BRCA_00045_0a384d70-52d9-4005-9a7c-b57434b03f47
# scores.shape (1793, 22884)
# downsampling: 1
# slide_gen_selectedlevel_idx: 17
# slide_gen_selectedlevel_dims: (70656, 90368)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (4416, 5648)
# (4416, 5648)
# target_size: (4416, 5648)
# img.size: (4416, 5648)
# mask_tile_size: 32
# heatmap.shape (5648, 4416)
# --- completed i_slide ---: 45
# n_slides: 1033
# i0: 50
# slide_name: BRCA_00050_0b657bec-490c-40a3-9213-0ec2ba805c95
# slide_level: 16
# idx_row_col.shape: (2337, 3)
# n_slides: 206
# i0: 8
# i_slide: 50
# slide_name: BRCA_00050_0b657bec-490c-40a3-9213-0ec2ba805c95
# scores.shape (2337, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (54264, 38325)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (6782, 4790)
# (6782, 4790)
# target_size: (6782, 4790)
# img.size: (6782, 4790)
# mask_tile_size: 64
# heatmap.shape (4790, 6782)
# --- completed i_slide ---: 50
# n_slides: 1033
# i0: 54
# slide_name: BRCA_00054_0cacb218-6f2d-46ca-b7be-4866d0f01e0c
# slide_level: 16
# idx_row_col.shape: (1493, 3)
# n_slides: 206
# i0: 9
# i_slide: 54
# slide_name: BRCA_00054_0cacb218-6f2d-46ca-b7be-4866d0f01e0c
# scores.shape (1493, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (39032, 34123)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (4879, 4265)
# (4879, 4265)
# target_size: (4879, 4265)
# img.size: (4879, 4265)
# mask_tile_size: 64
# heatmap.shape (4265, 4879)
# --- completed i_slide ---: 54
# n_slides: 1033
# i0: 55
# slide_name: BRCA_00055_0d463cf3-1de4-446d-869f-cc9cc4e390e5
# slide_level: 16
# idx_row_col.shape: (5686, 3)
# n_slides: 206
# i0: 10
# i_slide: 55
# slide_name: BRCA_00055_0d463cf3-1de4-446d-869f-cc9cc4e390e5
# scores.shape (5686, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (59370, 40665)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (7421, 5083)
# (7421, 5083)
# target_size: (7421, 5083)
# img.size: (7421, 5083)
# mask_tile_size: 64
# heatmap.shape (5083, 7421)
# --- completed i_slide ---: 55
# n_slides: 1033
# i0: 64
# slide_name: BRCA_00065_0fb6149b-ffef-4585-896d-832a01f40dd2
# slide_level: 16
# idx_row_col.shape: (3280, 3)
# n_slides: 206
# i0: 11
# i_slide: 65
# slide_name: BRCA_00065_0fb6149b-ffef-4585-896d-832a01f40dd2
# scores.shape (3280, 22884)
# downsampling: 1
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (53927, 39998)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (3370, 2499)
# (3370, 2499)
# target_size: (3370, 2499)
# img.size: (3370, 2499)
# mask_tile_size: 32
# heatmap.shape (2499, 3370)
# --- completed i_slide ---: 65
# n_slides: 1033
# i0: 70
# slide_name: BRCA_00072_11145ced-6199-4229-8adc-f202fd560581
# slide_level: 16
# idx_row_col.shape: (1255, 3)
# n_slides: 206
# i0: 12
# i_slide: 72
# slide_name: BRCA_00072_11145ced-6199-4229-8adc-f202fd560581
# scores.shape (1255, 22884)
# downsampling: 1
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (43776, 29440)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (2736, 1840)
# (2736, 1840)
# target_size: (2736, 1840)
# img.size: (2736, 1840)
# mask_tile_size: 32
# heatmap.shape (1840, 2736)
# --- completed i_slide ---: 72
# n_slides: 1033
# i0: 79
# slide_name: BRCA_00082_1263c9dc-10aa-478b-938f-aa1e832b25d9
# slide_level: 17
# idx_row_col.shape: (3315, 3)
# n_slides: 206
# i0: 13
# i_slide: 82
# slide_name: BRCA_00082_1263c9dc-10aa-478b-938f-aa1e832b25d9
# scores.shape (3315, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 17
# slide_gen_selectedlevel_dims: (76160, 44168)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (9520, 5520)
# (9520, 5520)
# target_size: (9520, 5520)
# img.size: (9520, 5520)
# mask_tile_size: 64
# heatmap.shape (5520, 9520)
# --- completed i_slide ---: 82
# n_slides: 1033
# i0: 83
# slide_name: BRCA_00087_135e18d0-6ae1-4016-961e-57376648d758
# slide_level: 16
# idx_row_col.shape: (556, 3)
# n_slides: 206
# i0: 14
# i_slide: 87
# slide_name: BRCA_00087_135e18d0-6ae1-4016-961e-57376648d758
# scores.shape (556, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (32868, 28609)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (4108, 3576)
# (4108, 3576)
# target_size: (4108, 3576)
# img.size: (4108, 3576)
# mask_tile_size: 64
# heatmap.shape (3576, 4108)
# --- completed i_slide ---: 87
# n_slides: 1033
# i0: 84
# slide_name: BRCA_00088_14253bab-4469-4eef-9e1b-51413982db83
# slide_level: 16
# idx_row_col.shape: (1249, 3)
# n_slides: 206
# i0: 15
# i_slide: 88
# slide_name: BRCA_00088_14253bab-4469-4eef-9e1b-51413982db83
# scores.shape (1249, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (34564, 27791)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (4320, 3473)
# (4320, 3473)
# target_size: (4320, 3473)
# img.size: (4320, 3473)
# mask_tile_size: 64
# heatmap.shape (3473, 4320)
# --- completed i_slide ---: 88
# n_slides: 1033
# i0: 96
# slide_name: BRCA_00101_16d2bed8-4fe9-43ba-832a-4a193aa3309d
# slide_level: 15
# idx_row_col.shape: (286, 3)
# n_slides: 206
# i0: 16
# i_slide: 101
# slide_name: BRCA_00101_16d2bed8-4fe9-43ba-832a-4a193aa3309d
# scores.shape (286, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 15
# slide_gen_selectedlevel_dims: (16932, 20388)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (2116, 2548)
# (2116, 2548)
# target_size: (2116, 2548)
# img.size: (2116, 2548)
# mask_tile_size: 64
# heatmap.shape (2548, 2116)
# --- completed i_slide ---: 101
# n_slides: 1033
# i0: 102
# slide_name: BRCA_00108_185df674-3307-4ff6-9ccd-d35bfb2e9bc8
# slide_level: 16
# idx_row_col.shape: (1045, 3)
# n_slides: 206
# i0: 17
# i_slide: 108
# slide_name: BRCA_00108_185df674-3307-4ff6-9ccd-d35bfb2e9bc8
# scores.shape (1045, 22884)
# downsampling: 1
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (35855, 24057)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (2240, 1503)
# (2240, 1503)
# target_size: (2240, 1503)
# img.size: (2240, 1503)
# mask_tile_size: 32
# heatmap.shape (1503, 2240)
# --- completed i_slide ---: 108
# n_slides: 1033
# i0: 103
# slide_name: BRCA_00109_1869a4cb-19b9-45d2-bab7-ae05b4aa92ea
# slide_level: 16
# idx_row_col.shape: (1685, 3)
# n_slides: 206
# i0: 18
# i_slide: 109
# slide_name: BRCA_00109_1869a4cb-19b9-45d2-bab7-ae05b4aa92ea
# scores.shape (1685, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (49980, 36840)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (6247, 4605)
# (6247, 4605)
# target_size: (6247, 4605)
# img.size: (6247, 4605)
# mask_tile_size: 64
# heatmap.shape (4605, 6247)
# --- completed i_slide ---: 109
# n_slides: 1033
# i0: 105
# slide_name: BRCA_00111_18706608-158a-4426-991c-f8da0a25d853
# slide_level: 17
# idx_row_col.shape: (3879, 3)
# n_slides: 206
# i0: 19
# i_slide: 111
# slide_name: BRCA_00111_18706608-158a-4426-991c-f8da0a25d853
# scores.shape (3879, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 17
# slide_gen_selectedlevel_dims: (69972, 32545)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (8746, 4068)
# (8746, 4068)
# target_size: (8746, 4068)
# img.size: (8746, 4068)
# mask_tile_size: 64
# heatmap.shape (4068, 8746)
# --- completed i_slide ---: 111
# n_slides: 1033
# i0: 107
# slide_name: BRCA_00113_18ee014d-ebea-42ce-b824-4862c7375598
# slide_level: 16
# idx_row_col.shape: (2679, 3)
# n_slides: 206
# i0: 20
# i_slide: 113
# slide_name: BRCA_00113_18ee014d-ebea-42ce-b824-4862c7375598
# scores.shape (2679, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (38080, 29359)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (4759, 3669)
# (4759, 3669)
# target_size: (4759, 3669)
# img.size: (4759, 3669)
# mask_tile_size: 64
# heatmap.shape (3669, 4759)
# --- completed i_slide ---: 113
# n_slides: 1033
# i0: 118
# slide_name: BRCA_00128_1c19ab1d-0333-409b-ad93-b6a586406903
# slide_level: 16
# idx_row_col.shape: (2269, 3)
# n_slides: 206
# i0: 21
# i_slide: 128
# slide_name: BRCA_00128_1c19ab1d-0333-409b-ad93-b6a586406903
# scores.shape (2269, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (50456, 42012)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (6307, 5251)
# (6307, 5251)
# target_size: (6307, 5251)
# img.size: (6307, 5251)
# mask_tile_size: 64
# heatmap.shape (5251, 6307)
# --- completed i_slide ---: 128
# n_slides: 1033
# i0: 119
# slide_name: BRCA_00129_1c55f0d8-b0af-4a1e-84ef-f30aab5d749b
# slide_level: 14
# idx_row_col.shape: (128, 3)
# n_slides: 206
# i0: 22
# i_slide: 129
# slide_name: BRCA_00129_1c55f0d8-b0af-4a1e-84ef-f30aab5d749b
# scores.shape (128, 22884)
# [WARNING] openslide.PROPERTY_NAME_OBJECTIVE_POWER was not found. Assuming it is 40X, i_slide: 129
# downsampling: 2
# slide_gen_selectedlevel_idx: 14
# slide_gen_selectedlevel_dims: (10983, 11413)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (2745, 2853)
# (2745, 2853)
# target_size: (1372, 1426)
# img.size: (1372, 1426)
# mask_tile_size: 64
# heatmap.shape (1426, 1372)
# --- completed i_slide ---: 129
# n_slides: 1033
# i0: 134
# slide_name: BRCA_00144_1e4c40ac-59a8-47b7-b750-dce2e52834bc
# slide_level: 14
# idx_row_col.shape: (141, 3)
# n_slides: 206
# i0: 23
# i_slide: 144
# slide_name: BRCA_00144_1e4c40ac-59a8-47b7-b750-dce2e52834bc
# scores.shape (141, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 14
# slide_gen_selectedlevel_dims: (9960, 9271)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (2490, 2317)
# (2490, 2317)
# target_size: (1245, 1158)
# img.size: (1245, 1158)
# mask_tile_size: 64
# heatmap.shape (1158, 1245)
# --- completed i_slide ---: 144
# n_slides: 1033
# i0: 136
# slide_name: BRCA_00146_1ea0c52f-8f36-41bc-b58c-3e28ea52846d
# slide_level: 15
# idx_row_col.shape: (423, 3)
# n_slides: 206
# i0: 24
# i_slide: 146
# slide_name: BRCA_00146_1ea0c52f-8f36-41bc-b58c-3e28ea52846d
# scores.shape (423, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 15
# slide_gen_selectedlevel_dims: (18564, 21823)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (2320, 2727)
# (2320, 2727)
# target_size: (2320, 2727)
# img.size: (2320, 2727)
# mask_tile_size: 64
# heatmap.shape (2727, 2320)
# --- completed i_slide ---: 146
# n_slides: 1033
# i0: 137
# slide_name: BRCA_00147_1eebfcb3-f220-455b-8659-45c1fc4d74bf
# slide_level: 16
# idx_row_col.shape: (1387, 3)
# n_slides: 206
# i0: 25
# i_slide: 147
# slide_name: BRCA_00147_1eebfcb3-f220-455b-8659-45c1fc4d74bf
# scores.shape (1387, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (35431, 39656)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (4428, 4957)
# (4428, 4957)
# target_size: (4428, 4957)
# img.size: (4428, 4957)
# mask_tile_size: 64
# heatmap.shape (4957, 4428)
# --- completed i_slide ---: 147
# n_slides: 1033
# i0: 141
# slide_name: BRCA_00151_1fb019e1-6191-4d24-ac72-3f851cedae32
# slide_level: 17
# idx_row_col.shape: (2661, 3)
# n_slides: 206
# i0: 26
# i_slide: 151
# slide_name: BRCA_00151_1fb019e1-6191-4d24-ac72-3f851cedae32
# scores.shape (2661, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 17
# slide_gen_selectedlevel_dims: (67209, 31379)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (8401, 3922)
# (8401, 3922)
# target_size: (8401, 3922)
# img.size: (8401, 3922)
# mask_tile_size: 64
# heatmap.shape (3922, 8401)
# --- completed i_slide ---: 151
# n_slides: 1033
# i0: 145
# slide_name: BRCA_00155_2090bab5-1e6d-476a-b8f4-0d4c3d02cc0b
# slide_level: 15
# idx_row_col.shape: (1353, 3)
# n_slides: 206
# i0: 27
# i_slide: 155
# slide_name: BRCA_00155_2090bab5-1e6d-476a-b8f4-0d4c3d02cc0b
# scores.shape (1353, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 15
# slide_gen_selectedlevel_dims: (32368, 28536)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (4046, 3567)
# (4046, 3567)
# target_size: (4046, 3567)
# img.size: (4046, 3567)
# mask_tile_size: 64
# heatmap.shape (3567, 4046)
# --- completed i_slide ---: 155
# n_slides: 1033
# i0: 148
# slide_name: BRCA_00158_20c1e1ce-65d5-40dd-924b-a1bb905d2963
# slide_level: 16
# idx_row_col.shape: (3822, 3)
# n_slides: 206
# i0: 28
# i_slide: 158
# slide_name: BRCA_00158_20c1e1ce-65d5-40dd-924b-a1bb905d2963
# scores.shape (3822, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (61404, 40932)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (7675, 5116)
# (7675, 5116)
# target_size: (7675, 5116)
# img.size: (7675, 5116)
# mask_tile_size: 64
# heatmap.shape (5116, 7675)
# --- completed i_slide ---: 158
# n_slides: 1033
# i0: 151
# slide_name: BRCA_00162_2218cbeb-b088-49d0-bfbb-9370057d99ee
# slide_level: 16
# idx_row_col.shape: (1872, 3)
# n_slides: 206
# i0: 29
# i_slide: 162
# slide_name: BRCA_00162_2218cbeb-b088-49d0-bfbb-9370057d99ee
# scores.shape (1872, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (49926, 44433)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (6240, 5554)
# (6240, 5554)
# target_size: (6240, 5554)
# img.size: (6240, 5554)
# mask_tile_size: 64
# heatmap.shape (5554, 6240)
# --- completed i_slide ---: 162
# n_slides: 1033
# i0: 154
# slide_name: BRCA_00165_22b53aed-2db1-498c-8a6b-cb2f995e4b62
# slide_level: 16
# idx_row_col.shape: (3430, 3)
# n_slides: 206
# i0: 30
# i_slide: 165
# slide_name: BRCA_00165_22b53aed-2db1-498c-8a6b-cb2f995e4b62
# scores.shape (3430, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (52667, 39428)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (6583, 4928)
# (6583, 4928)
# target_size: (6583, 4928)
# img.size: (6583, 4928)
# mask_tile_size: 64
# heatmap.shape (4928, 6583)
# --- completed i_slide ---: 165
# n_slides: 1033
# i0: 159
# slide_name: BRCA_00170_23808d51-3e71-4f8e-ba52-6d90036408a4
# slide_level: 17
# idx_row_col.shape: (2751, 3)
# n_slides: 206
# i0: 31
# i_slide: 170
# slide_name: BRCA_00170_23808d51-3e71-4f8e-ba52-6d90036408a4
# scores.shape (2751, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 17
# slide_gen_selectedlevel_dims: (68468, 43162)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (8558, 5395)
# (8558, 5395)
# target_size: (8558, 5395)
# img.size: (8558, 5395)
# mask_tile_size: 64
# heatmap.shape (5395, 8558)
# --- completed i_slide ---: 170
# n_slides: 1033
# i0: 163
# slide_name: BRCA_00174_2412b00e-b796-492e-b475-1b7ff7661ab7
# slide_level: 16
# idx_row_col.shape: (2325, 3)
# n_slides: 206
# i0: 32
# i_slide: 174
# slide_name: BRCA_00174_2412b00e-b796-492e-b475-1b7ff7661ab7
# scores.shape (2325, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (53312, 39958)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (6664, 4994)
# (6664, 4994)
# target_size: (6664, 4994)
# img.size: (6664, 4994)
# mask_tile_size: 64
# heatmap.shape (4994, 6664)
# --- completed i_slide ---: 174
# n_slides: 1033
# i0: 165
# slide_name: BRCA_00176_2455409e-71d3-4eda-a60d-f520460446e0
# slide_level: 16
# idx_row_col.shape: (3382, 3)
# n_slides: 206
# i0: 33
# i_slide: 176
# slide_name: BRCA_00176_2455409e-71d3-4eda-a60d-f520460446e0
# scores.shape (3382, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (51884, 34388)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (6485, 4298)
# (6485, 4298)
# target_size: (6485, 4298)
# img.size: (6485, 4298)
# mask_tile_size: 64
# heatmap.shape (4298, 6485)
# --- completed i_slide ---: 176
# n_slides: 1033
# i0: 170
# slide_name: BRCA_00181_262bfde9-6bd1-45eb-9b92-ea7b23283a4d
# slide_level: 16
# idx_row_col.shape: (1014, 3)
# n_slides: 206
# i0: 34
# i_slide: 181
# slide_name: BRCA_00181_262bfde9-6bd1-45eb-9b92-ea7b23283a4d
# scores.shape (1014, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (49980, 35982)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (6247, 4497)
# (6247, 4497)
# target_size: (6247, 4497)
# img.size: (6247, 4497)
# mask_tile_size: 64
# heatmap.shape (4497, 6247)
# --- completed i_slide ---: 181
# n_slides: 1033
# i0: 181
# slide_name: BRCA_00194_28d502d3-32d1-4a75-9a69-3780809efc84
# slide_level: 16
# idx_row_col.shape: (3420, 3)
# n_slides: 206
# i0: 35
# i_slide: 194
# slide_name: BRCA_00194_28d502d3-32d1-4a75-9a69-3780809efc84
# scores.shape (3420, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (57934, 41054)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (7241, 5131)
# (7241, 5131)
# target_size: (7241, 5131)
# img.size: (7241, 5131)
# mask_tile_size: 64
# heatmap.shape (5131, 7241)
# --- completed i_slide ---: 194
# n_slides: 1033
# i0: 183
# slide_name: BRCA_00196_29766363-7efc-4f7b-93a3-aaf5bb6507d4
# slide_level: 16
# idx_row_col.shape: (404, 3)
# n_slides: 206
# i0: 36
# i_slide: 196
# slide_name: BRCA_00196_29766363-7efc-4f7b-93a3-aaf5bb6507d4
# scores.shape (404, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (55692, 37509)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (6961, 4688)
# (6961, 4688)
# target_size: (6961, 4688)
# img.size: (6961, 4688)
# mask_tile_size: 64
# heatmap.shape (4688, 6961)
# --- completed i_slide ---: 196
# n_slides: 1033
# i0: 184
# slide_name: BRCA_00197_29cf7f50-132d-4856-88f9-215e58e66f77
# slide_level: 16
# idx_row_col.shape: (1381, 3)
# n_slides: 206
# i0: 37
# i_slide: 197
# slide_name: BRCA_00197_29cf7f50-132d-4856-88f9-215e58e66f77
# scores.shape (1381, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (62356, 31216)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (7794, 3902)
# (7794, 3902)
# target_size: (7794, 3902)
# img.size: (7794, 3902)
# mask_tile_size: 64
# heatmap.shape (3902, 7794)
# --- completed i_slide ---: 197
# n_slides: 1033
# i0: 185
# slide_name: BRCA_00198_2a461b20-1d1a-4283-845a-cb58483a0eb5
# slide_level: 15
# idx_row_col.shape: (1263, 3)
# n_slides: 206
# i0: 38
# i_slide: 198
# slide_name: BRCA_00198_2a461b20-1d1a-4283-845a-cb58483a0eb5
# scores.shape (1263, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 15
# slide_gen_selectedlevel_dims: (27132, 27898)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (3391, 3487)
# (3391, 3487)
# target_size: (3391, 3487)
# img.size: (3391, 3487)
# mask_tile_size: 64
# heatmap.shape (3487, 3391)
# --- completed i_slide ---: 198
# n_slides: 1033
# i0: 186
# slide_name: BRCA_00199_2a913d67-f78d-41a0-87fa-96a3a7482c95
# slide_level: 16
# idx_row_col.shape: (2008, 3)
# n_slides: 206
# i0: 39
# i_slide: 199
# slide_name: BRCA_00199_2a913d67-f78d-41a0-87fa-96a3a7482c95
# scores.shape (2008, 22884)
# downsampling: 1
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (44288, 41216)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (2768, 2576)
# (2768, 2576)
# target_size: (2768, 2576)
# img.size: (2768, 2576)
# mask_tile_size: 32
# heatmap.shape (2576, 2768)
# --- completed i_slide ---: 199
# n_slides: 1033
# i0: 187
# slide_name: BRCA_00200_2aa667bd-8a80-4461-b561-cde361796082
# slide_level: 16
# idx_row_col.shape: (1933, 3)
# n_slides: 206
# i0: 40
# i_slide: 200
# slide_name: BRCA_00200_2aa667bd-8a80-4461-b561-cde361796082
# scores.shape (1933, 22884)
# downsampling: 1
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (59759, 44513)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (3734, 2782)
# (3734, 2782)
# target_size: (3734, 2782)
# img.size: (3734, 2782)
# mask_tile_size: 32
# heatmap.shape (2782, 3734)
# --- completed i_slide ---: 200
# n_slides: 1033
# i0: 189
# slide_name: BRCA_00202_2b87cfa4-efde-4890-8887-e4a0aa2f4f1b
# slide_level: 16
# idx_row_col.shape: (2025, 3)
# n_slides: 206
# i0: 41
# i_slide: 202
# slide_name: BRCA_00202_2b87cfa4-efde-4890-8887-e4a0aa2f4f1b
# scores.shape (2025, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (48552, 42378)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (6069, 5297)
# (6069, 5297)
# target_size: (6069, 5297)
# img.size: (6069, 5297)
# mask_tile_size: 64
# heatmap.shape (5297, 6069)
# --- completed i_slide ---: 202
# n_slides: 1033
# i0: 191
# slide_name: BRCA_00204_2bbc6faf-ecfb-4587-a5d1-bbc188d2abb7
# slide_level: 16
# idx_row_col.shape: (1463, 3)
# n_slides: 206
# i0: 42
# i_slide: 204
# slide_name: BRCA_00204_2bbc6faf-ecfb-4587-a5d1-bbc188d2abb7
# scores.shape (1463, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (50456, 41674)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (6306, 5209)
# (6306, 5209)
# target_size: (6306, 5209)
# img.size: (6306, 5209)
# mask_tile_size: 64
# heatmap.shape (5209, 6306)
# --- completed i_slide ---: 204
# n_slides: 1033
# i0: 198
# slide_name: BRCA_00211_2dac5c90-0281-434e-ad17-9a2fe3e0c5c6
# slide_level: 17
# idx_row_col.shape: (1912, 3)
# n_slides: 206
# i0: 43
# i_slide: 211
# slide_name: BRCA_00211_2dac5c90-0281-434e-ad17-9a2fe3e0c5c6
# scores.shape (1912, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 17
# slide_gen_selectedlevel_dims: (66640, 44696)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (8330, 5587)
# (8330, 5587)
# target_size: (8330, 5587)
# img.size: (8330, 5587)
# mask_tile_size: 64
# heatmap.shape (5587, 8330)
# --- completed i_slide ---: 211
# n_slides: 1033
# i0: 202
# slide_name: BRCA_00215_2e970b64-b3ee-4929-8fcc-8d9a126146d9
# slide_level: 16
# idx_row_col.shape: (1652, 3)
# n_slides: 206
# i0: 44
# i_slide: 215
# slide_name: BRCA_00215_2e970b64-b3ee-4929-8fcc-8d9a126146d9
# scores.shape (1652, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (34748, 35924)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (4343, 4490)
# (4343, 4490)
# target_size: (4343, 4490)
# img.size: (4343, 4490)
# mask_tile_size: 64
# heatmap.shape (4490, 4343)
# --- completed i_slide ---: 215
# n_slides: 1033
# i0: 204
# slide_name: BRCA_00217_2f9d23e6-9bd4-4a63-8277-3410c04010f8
# slide_level: 16
# idx_row_col.shape: (3033, 3)
# n_slides: 206
# i0: 45
# i_slide: 217
# slide_name: BRCA_00217_2f9d23e6-9bd4-4a63-8277-3410c04010f8
# scores.shape (3033, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (64637, 46881)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (8079, 5860)
# (8079, 5860)
# target_size: (8079, 5860)
# img.size: (8079, 5860)
# mask_tile_size: 64
# heatmap.shape (5860, 8079)
# --- completed i_slide ---: 217
# n_slides: 1033
# i0: 205
# slide_name: BRCA_00218_300b6dbe-bff1-4536-ac1b-edc898dc821e
# slide_level: 16
# idx_row_col.shape: (1749, 3)
# n_slides: 206
# i0: 46
# i_slide: 218
# slide_name: BRCA_00218_300b6dbe-bff1-4536-ac1b-edc898dc821e
# scores.shape (1749, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (46172, 44532)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (5771, 5566)
# (5771, 5566)
# target_size: (5771, 5566)
# img.size: (5771, 5566)
# mask_tile_size: 64
# heatmap.shape (5566, 5771)
# --- completed i_slide ---: 218
# n_slides: 1033
# i0: 210
# slide_name: BRCA_00223_31e248bf-ee24-4d18-bccb-47046fccb461
# slide_level: 16
# idx_row_col.shape: (2341, 3)
# n_slides: 206
# i0: 47
# i_slide: 223
# slide_name: BRCA_00223_31e248bf-ee24-4d18-bccb-47046fccb461
# scores.shape (2341, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (60928, 47349)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (7616, 5918)
# (7616, 5918)
# target_size: (7616, 5918)
# img.size: (7616, 5918)
# mask_tile_size: 64
# heatmap.shape (5918, 7616)
# --- completed i_slide ---: 223
# n_slides: 1033
# i0: 211
# slide_name: BRCA_00224_325f5618-c268-430f-ac18-3aee632caa05
# slide_level: 17
# idx_row_col.shape: (666, 3)
# n_slides: 206
# i0: 48
# i_slide: 224
# slide_name: BRCA_00224_325f5618-c268-430f-ac18-3aee632caa05
# scores.shape (666, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 17
# slide_gen_selectedlevel_dims: (91392, 27252)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (11424, 3406)
# (11424, 3406)
# target_size: (11424, 3406)
# img.size: (11424, 3406)
# mask_tile_size: 64
# heatmap.shape (3406, 11424)
# --- completed i_slide ---: 224
# n_slides: 1033
# i0: 215
# slide_name: BRCA_00228_337ea2e7-d54c-4a45-a5cd-7e2817a86e6a
# slide_level: 16
# idx_row_col.shape: (1396, 3)
# n_slides: 206
# i0: 49
# i_slide: 228
# slide_name: BRCA_00228_337ea2e7-d54c-4a45-a5cd-7e2817a86e6a
# scores.shape (1396, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (62722, 39880)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (7840, 4984)
# (7840, 4984)
# target_size: (7840, 4984)
# img.size: (7840, 4984)
# mask_tile_size: 64
# heatmap.shape (4984, 7840)
# --- completed i_slide ---: 228
# n_slides: 1033
# i0: 218
# slide_name: BRCA_00231_34d23db9-fe38-431a-9119-b4297eaccbdf
# slide_level: 16
# idx_row_col.shape: (1262, 3)
# n_slides: 206
# i0: 50
# i_slide: 231
# slide_name: BRCA_00231_34d23db9-fe38-431a-9119-b4297eaccbdf
# scores.shape (1262, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (35700, 27834)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (4462, 3479)
# (4462, 3479)
# target_size: (4462, 3479)
# img.size: (4462, 3479)
# mask_tile_size: 64
# heatmap.shape (3479, 4462)
# --- completed i_slide ---: 231
# n_slides: 1033
# i0: 223
# slide_name: BRCA_00236_369fc592-8ce1-4c6b-aaf6-434aed9e4f71
# slide_level: 16
# idx_row_col.shape: (1301, 3)
# n_slides: 206
# i0: 51
# i_slide: 236
# slide_name: BRCA_00236_369fc592-8ce1-4c6b-aaf6-434aed9e4f71
# scores.shape (1301, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (45696, 37813)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (5711, 4726)
# (5711, 4726)
# target_size: (5711, 4726)
# img.size: (5711, 4726)
# mask_tile_size: 64
# heatmap.shape (4726, 5711)
# --- completed i_slide ---: 236
# n_slides: 1033
# i0: 225
# slide_name: BRCA_00238_3703a961-f8eb-4b2e-8fb3-ebeb8f5cb83c
# slide_level: 16
# idx_row_col.shape: (2381, 3)
# n_slides: 206
# i0: 52
# i_slide: 238
# slide_name: BRCA_00238_3703a961-f8eb-4b2e-8fb3-ebeb8f5cb83c
# scores.shape (2381, 22884)
# [WARNING] openslide.PROPERTY_NAME_OBJECTIVE_POWER was not found. Assuming it is 40X, i_slide: 238
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (50592, 37216)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (6324, 4652)
# (6324, 4652)
# target_size: (6324, 4652)
# img.size: (6324, 4652)
# mask_tile_size: 64
# heatmap.shape (4652, 6324)
# --- completed i_slide ---: 238
# n_slides: 1033
# i0: 226
# slide_name: BRCA_00239_371197b5-7f16-422b-b191-a02c917db652
# slide_level: 16
# idx_row_col.shape: (1824, 3)
# n_slides: 206
# i0: 53
# i_slide: 239
# slide_name: BRCA_00239_371197b5-7f16-422b-b191-a02c917db652
# scores.shape (1824, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (58764, 41816)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (7345, 5227)
# (7345, 5227)
# target_size: (7345, 5227)
# img.size: (7345, 5227)
# mask_tile_size: 64
# heatmap.shape (5227, 7345)
# --- completed i_slide ---: 239
# n_slides: 1033
# i0: 232
# slide_name: BRCA_00245_3830c248-4ba1-4a58-b564-f658a320ed5b
# slide_level: 16
# idx_row_col.shape: (1583, 3)
# n_slides: 206
# i0: 54
# i_slide: 245
# slide_name: BRCA_00245_3830c248-4ba1-4a58-b564-f658a320ed5b
# scores.shape (1583, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (46566, 40904)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (5820, 5112)
# (5820, 5112)
# target_size: (5820, 5112)
# img.size: (5820, 5112)
# mask_tile_size: 64
# heatmap.shape (5112, 5820)
# --- completed i_slide ---: 245
# n_slides: 1033
# i0: 242
# slide_name: BRCA_00255_3aedb887-b2a1-4760-9d68-1bf318c26a9d
# slide_level: 16
# idx_row_col.shape: (2802, 3)
# n_slides: 206
# i0: 55
# i_slide: 255
# slide_name: BRCA_00255_3aedb887-b2a1-4760-9d68-1bf318c26a9d
# scores.shape (2802, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (40836, 45087)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (5104, 5635)
# (5104, 5635)
# target_size: (5104, 5635)
# img.size: (5104, 5635)
# mask_tile_size: 64
# heatmap.shape (5635, 5104)
# --- completed i_slide ---: 255
# n_slides: 1033
# i0: 244
# slide_name: BRCA_00257_3b53c5b2-a2a6-4cb0-90dc-1fa309a6532b
# slide_level: 16
# idx_row_col.shape: (1258, 3)
# n_slides: 206
# i0: 56
# i_slide: 257
# slide_name: BRCA_00257_3b53c5b2-a2a6-4cb0-90dc-1fa309a6532b
# scores.shape (1258, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (51847, 32932)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (6480, 4116)
# (6480, 4116)
# target_size: (6480, 4116)
# img.size: (6480, 4116)
# mask_tile_size: 64
# heatmap.shape (4116, 6480)
# --- completed i_slide ---: 257
# n_slides: 1033
# i0: 251
# slide_name: BRCA_00264_3cfa3a11-b572-484b-aac2-c8d2ce66770d
# slide_level: 16
# idx_row_col.shape: (1266, 3)
# n_slides: 206
# i0: 57
# i_slide: 264
# slide_name: BRCA_00264_3cfa3a11-b572-484b-aac2-c8d2ce66770d
# scores.shape (1266, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (56498, 41573)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (7062, 5196)
# (7062, 5196)
# target_size: (7062, 5196)
# img.size: (7062, 5196)
# mask_tile_size: 64
# heatmap.shape (5196, 7062)
# --- completed i_slide ---: 264
# n_slides: 1033
# i0: 255
# slide_name: BRCA_00268_3deb9b07-a88a-4401-a589-8cd721e16c9a
# slide_level: 16
# idx_row_col.shape: (2165, 3)
# n_slides: 206
# i0: 58
# i_slide: 268
# slide_name: BRCA_00268_3deb9b07-a88a-4401-a589-8cd721e16c9a
# scores.shape (2165, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (59500, 32304)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (7437, 4037)
# (7437, 4037)
# target_size: (7437, 4037)
# img.size: (7437, 4037)
# mask_tile_size: 64
# heatmap.shape (4037, 7437)
# --- completed i_slide ---: 268
# n_slides: 1033
# i0: 256
# slide_name: BRCA_00269_3df8a36d-4871-4f0d-8ad1-6c7aa001b2f2
# slide_level: 16
# idx_row_col.shape: (1920, 3)
# n_slides: 206
# i0: 59
# i_slide: 269
# slide_name: BRCA_00269_3df8a36d-4871-4f0d-8ad1-6c7aa001b2f2
# scores.shape (1920, 22884)
# downsampling: 1
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (41831, 45512)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (2614, 2844)
# (2614, 2844)
# target_size: (2614, 2844)
# img.size: (2614, 2844)
# mask_tile_size: 32
# heatmap.shape (2844, 2614)
# --- completed i_slide ---: 269
# n_slides: 1033
# i0: 261
# slide_name: BRCA_00274_406aa150-f7b8-4b36-ba50-dfbd6ddff42d
# slide_level: 16
# idx_row_col.shape: (2667, 3)
# n_slides: 206
# i0: 60
# i_slide: 274
# slide_name: BRCA_00274_406aa150-f7b8-4b36-ba50-dfbd6ddff42d
# scores.shape (2667, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (55216, 46600)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (6901, 5824)
# (6901, 5824)
# target_size: (6901, 5824)
# img.size: (6901, 5824)
# mask_tile_size: 64
# heatmap.shape (5824, 6901)
# --- completed i_slide ---: 274
# n_slides: 1033
# i0: 282
# slide_name: BRCA_00295_48ab91f1-dd5c-4e67-8e52-61334afcb1fc
# slide_level: 17
# idx_row_col.shape: (3264, 3)
# n_slides: 206
# i0: 61
# i_slide: 295
# slide_name: BRCA_00295_48ab91f1-dd5c-4e67-8e52-61334afcb1fc
# scores.shape (3264, 22884)
# downsampling: 1
# slide_gen_selectedlevel_idx: 17
# slide_gen_selectedlevel_dims: (53504, 86784)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (3344, 5424)
# (3344, 5424)
# target_size: (3344, 5424)
# img.size: (3344, 5424)
# mask_tile_size: 32
# heatmap.shape (5424, 3344)
# --- completed i_slide ---: 295
# n_slides: 1033
# i0: 283
# slide_name: BRCA_00296_48e21e8f-34f1-4da5-9d67-e2003d905a6c
# slide_level: 17
# idx_row_col.shape: (688, 3)
# n_slides: 206
# i0: 62
# i_slide: 296
# slide_name: BRCA_00296_48e21e8f-34f1-4da5-9d67-e2003d905a6c
# scores.shape (688, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 17
# slide_gen_selectedlevel_dims: (67116, 17955)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (8389, 2244)
# (8389, 2244)
# target_size: (8389, 2244)
# img.size: (8389, 2244)
# mask_tile_size: 64
# heatmap.shape (2244, 8389)
# --- completed i_slide ---: 296
# n_slides: 1033
# i0: 284
# slide_name: BRCA_00297_49278c78-18fd-4609-9b0b-a7ef89e8b3c1
# slide_level: 16
# idx_row_col.shape: (638, 3)
# n_slides: 206
# i0: 63
# i_slide: 297
# slide_name: BRCA_00297_49278c78-18fd-4609-9b0b-a7ef89e8b3c1
# scores.shape (638, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (56168, 37409)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (7021, 4676)
# (7021, 4676)
# target_size: (7021, 4676)
# img.size: (7021, 4676)
# mask_tile_size: 64
# heatmap.shape (4676, 7021)
# --- completed i_slide ---: 297
# n_slides: 1033
# i0: 285
# slide_name: BRCA_00298_49440444-06c7-40e4-8be1-782a04a9f1d1
# slide_level: 16
# idx_row_col.shape: (1377, 3)
# n_slides: 206
# i0: 64
# i_slide: 298
# slide_name: BRCA_00298_49440444-06c7-40e4-8be1-782a04a9f1d1
# scores.shape (1377, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (41832, 36763)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (5228, 4595)
# (5228, 4595)
# target_size: (5228, 4595)
# img.size: (5228, 4595)
# mask_tile_size: 64
# heatmap.shape (4595, 5228)
# --- completed i_slide ---: 298
# n_slides: 1033
# i0: 296
# slide_name: BRCA_00309_4abe8617-3e78-4f36-a066-977fb94268fb
# slide_level: 16
# idx_row_col.shape: (4029, 3)
# n_slides: 206
# i0: 65
# i_slide: 309
# slide_name: BRCA_00309_4abe8617-3e78-4f36-a066-977fb94268fb
# scores.shape (4029, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (60928, 45138)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (7615, 5642)
# (7615, 5642)
# target_size: (7615, 5642)
# img.size: (7615, 5642)
# mask_tile_size: 64
# heatmap.shape (5642, 7615)
# --- completed i_slide ---: 309
# n_slides: 1033
# i0: 307
# slide_name: BRCA_00320_4e45f217-02a0-4f90-b463-c1f64d98567b
# slide_level: 16
# idx_row_col.shape: (2875, 3)
# n_slides: 206
# i0: 66
# i_slide: 320
# slide_name: BRCA_00320_4e45f217-02a0-4f90-b463-c1f64d98567b
# scores.shape (2875, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (57768, 37611)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (7221, 4701)
# (7221, 4701)
# target_size: (7221, 4701)
# img.size: (7221, 4701)
# mask_tile_size: 64
# heatmap.shape (4701, 7221)
# --- completed i_slide ---: 320
# n_slides: 1033
# i0: 321
# slide_name: BRCA_00334_51ea2d58-82ba-4f5d-a6e1-4192852ce9f1
# slide_level: 17
# idx_row_col.shape: (4968, 3)
# n_slides: 206
# i0: 67
# i_slide: 334
# slide_name: BRCA_00334_51ea2d58-82ba-4f5d-a6e1-4192852ce9f1
# scores.shape (4968, 22884)
# downsampling: 1
# slide_gen_selectedlevel_idx: 17
# slide_gen_selectedlevel_dims: (58112, 73472)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (3632, 4592)
# (3632, 4592)
# target_size: (3632, 4592)
# img.size: (3632, 4592)
# mask_tile_size: 32
# heatmap.shape (4592, 3632)
# --- completed i_slide ---: 334
# n_slides: 1033
# i0: 326
# slide_name: BRCA_00339_541335eb-b2af-475e-9e7b-8e29530fbaf1
# slide_level: 17
# idx_row_col.shape: (3339, 3)
# n_slides: 206
# i0: 68
# i_slide: 339
# slide_name: BRCA_00339_541335eb-b2af-475e-9e7b-8e29530fbaf1
# scores.shape (3339, 22884)
# downsampling: 1
# slide_gen_selectedlevel_idx: 17
# slide_gen_selectedlevel_dims: (61440, 107264)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (3840, 6704)
# (3840, 6704)
# target_size: (3840, 6704)
# img.size: (3840, 6704)
# mask_tile_size: 32
# heatmap.shape (6704, 3840)
# --- completed i_slide ---: 339
# n_slides: 1033
# i0: 330
# slide_name: BRCA_00343_54cff200-45f7-43d9-9e03-0e04dd7fea08
# slide_level: 17
# idx_row_col.shape: (2648, 3)
# n_slides: 206
# i0: 69
# i_slide: 343
# slide_name: BRCA_00343_54cff200-45f7-43d9-9e03-0e04dd7fea08
# scores.shape (2648, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 17
# slide_gen_selectedlevel_dims: (66164, 45969)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (8270, 5746)
# (8270, 5746)
# target_size: (8270, 5746)
# img.size: (8270, 5746)
# mask_tile_size: 64
# heatmap.shape (5746, 8270)
# --- completed i_slide ---: 343
# n_slides: 1033
# i0: 331
# slide_name: BRCA_00344_55263429-73b2-4205-880f-d39ad296144e
# slide_level: 17
# idx_row_col.shape: (2584, 3)
# n_slides: 206
# i0: 70
# i_slide: 344
# slide_name: BRCA_00344_55263429-73b2-4205-880f-d39ad296144e
# scores.shape (2584, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 17
# slide_gen_selectedlevel_dims: (93844, 40717)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (11730, 5089)
# (11730, 5089)
# target_size: (11730, 5089)
# img.size: (11730, 5089)
# mask_tile_size: 64
# heatmap.shape (5089, 11730)
# --- completed i_slide ---: 344
# n_slides: 1033
# i0: 332
# slide_name: BRCA_00345_55458100-7acc-4c2b-aa46-a767a94f6d3f
# slide_level: 16
# idx_row_col.shape: (2486, 3)
# n_slides: 206
# i0: 71
# i_slide: 345
# slide_name: BRCA_00345_55458100-7acc-4c2b-aa46-a767a94f6d3f
# scores.shape (2486, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (40219, 37333)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (5027, 4666)
# (5027, 4666)
# target_size: (5027, 4666)
# img.size: (5027, 4666)
# mask_tile_size: 64
# heatmap.shape (4666, 5027)
# --- completed i_slide ---: 345
# n_slides: 1033
# i0: 333
# slide_name: BRCA_00346_558a3a47-68a7-4e87-ac3a-434c06d0b114
# slide_level: 16
# idx_row_col.shape: (3402, 3)
# n_slides: 206
# i0: 72
# i_slide: 346
# slide_name: BRCA_00346_558a3a47-68a7-4e87-ac3a-434c06d0b114
# scores.shape (3402, 22884)
# downsampling: 1
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (49408, 64256)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (3088, 4016)
# (3088, 4016)
# target_size: (3088, 4016)
# img.size: (3088, 4016)
# mask_tile_size: 32
# heatmap.shape (4016, 3088)
# --- completed i_slide ---: 346
# n_slides: 1033
# i0: 343
# slide_name: BRCA_00356_57bf193f-3d10-4a1d-983b-c6b4ec4f79c2
# slide_level: 17
# idx_row_col.shape: (4488, 3)
# n_slides: 206
# i0: 73
# i_slide: 356
# slide_name: BRCA_00356_57bf193f-3d10-4a1d-983b-c6b4ec4f79c2
# scores.shape (4488, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 17
# slide_gen_selectedlevel_dims: (96238, 39809)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (12029, 4976)
# (12029, 4976)
# target_size: (12029, 4976)
# img.size: (12029, 4976)
# mask_tile_size: 64
# heatmap.shape (4976, 12029)
# --- completed i_slide ---: 356
# n_slides: 1033
# i0: 353
# slide_name: BRCA_00366_5acb2392-1739-4117-b899-2bc0fa5601b5
# slide_level: 16
# idx_row_col.shape: (2515, 3)
# n_slides: 206
# i0: 74
# i_slide: 366
# slide_name: BRCA_00366_5acb2392-1739-4117-b899-2bc0fa5601b5
# scores.shape (2515, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (41888, 39935)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (5236, 4991)
# (5236, 4991)
# target_size: (5236, 4991)
# img.size: (5236, 4991)
# mask_tile_size: 64
# heatmap.shape (4991, 5236)
# --- completed i_slide ---: 366
# n_slides: 1033
# i0: 361
# slide_name: BRCA_00374_5c4ef2a4-9bd0-43bb-829c-8ce975603a9d
# slide_level: 18
# idx_row_col.shape: (1313, 3)
# n_slides: 206
# i0: 75
# i_slide: 374
# slide_name: BRCA_00374_5c4ef2a4-9bd0-43bb-829c-8ce975603a9d
# scores.shape (1313, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 18
# slide_gen_selectedlevel_dims: (83968, 210048)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (10496, 26256)
# (10496, 26256)
# target_size: (10496, 26256)
# img.size: (10496, 26256)
# mask_tile_size: 64
# heatmap.shape (26256, 10496)
# --- completed i_slide ---: 374
# n_slides: 1033
# i0: 363
# slide_name: BRCA_00376_5ca8d2a8-827a-448d-a3a7-f9b965f925a4
# slide_level: 16
# idx_row_col.shape: (1097, 3)
# n_slides: 206
# i0: 76
# i_slide: 376
# slide_name: BRCA_00376_5ca8d2a8-827a-448d-a3a7-f9b965f925a4
# scores.shape (1097, 22884)
# downsampling: 1
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (37632, 41216)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (2352, 2576)
# (2352, 2576)
# target_size: (2352, 2576)
# img.size: (2352, 2576)
# mask_tile_size: 32
# heatmap.shape (2576, 2352)
# --- completed i_slide ---: 376
# n_slides: 1033
# i0: 380
# slide_name: BRCA_00393_61afff86-4563-482e-a64b-fbab63507ad0
# slide_level: 16
# idx_row_col.shape: (4322, 3)
# n_slides: 206
# i0: 77
# i_slide: 393
# slide_name: BRCA_00393_61afff86-4563-482e-a64b-fbab63507ad0
# scores.shape (4322, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (57934, 39780)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (7241, 4972)
# (7241, 4972)
# target_size: (7241, 4972)
# img.size: (7241, 4972)
# mask_tile_size: 64
# heatmap.shape (4972, 7241)
# --- completed i_slide ---: 393
# n_slides: 1033
# i0: 395
# slide_name: BRCA_00408_645c0ecb-8451-4936-b649-8bac3568c2af
# slide_level: 16
# idx_row_col.shape: (2533, 3)
# n_slides: 206
# i0: 78
# i_slide: 408
# slide_name: BRCA_00408_645c0ecb-8451-4936-b649-8bac3568c2af
# scores.shape (2533, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (65116, 45477)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (8139, 5684)
# (8139, 5684)
# target_size: (8139, 5684)
# img.size: (8139, 5684)
# mask_tile_size: 64
# heatmap.shape (5684, 8139)
# --- completed i_slide ---: 408
# n_slides: 1033
# i0: 399
# slide_name: BRCA_00412_6585947b-c746-4a95-a9e8-8de23a1dce45
# slide_level: 16
# idx_row_col.shape: (1386, 3)
# n_slides: 206
# i0: 79
# i_slide: 412
# slide_name: BRCA_00412_6585947b-c746-4a95-a9e8-8de23a1dce45
# scores.shape (1386, 22884)
# downsampling: 2
# slide_gen_selectedlevel_idx: 16
# slide_gen_selectedlevel_dims: (48552, 39540)
# best_downsampling_level: 2
# slide.level_dimensions[best_downsampling_level]: (6068, 4942)
# (6068, 4942)
# target_size: (6068, 4942)
# img.size: (6068, 4942)
# mask_tile_size: 64
# heatmap.shape (4942, 6068)
# --- completed i_slide ---: 412
